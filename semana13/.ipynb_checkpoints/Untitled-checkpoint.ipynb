# %%
import numpy as np
import matplotlib.pyplot as plt

a = 6
h = 3
w = 1

x = np.arange(0,20,0.1)
y = a*np.cos(w*x)+h

plt.plot(x,y)
plt.xlabel('tiempo(s)')
plt.ylabel('altura(m)')
plt.title('Movimiento armonico simple')
plt.show()
